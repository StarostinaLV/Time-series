# %% [markdown]
# #**Задание**
# **«Модели авторегрессии условной гетероскедаcтичности»**
#
# Выберите ряд из первого задания.
#
# Постройте его модель GARCH.
#
# Оформите отчёт в Jupyter-ноутбук.

# %% [markdown]
# **Исследуемый временной ряд - продажи компании Х  ("monthly-sales-of-company-x-jan-6.csv").**

# %% [markdown]
# Установка необходимых библиотек и модулей

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.stattools import adfuller
import statsmodels.tsa.api as smt
from math import sqrt
import warnings
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !pip install arch
# Out:
# Requirement already satisfied: arch in /usr/local/lib/python3.10/dist-packages (6.3.0)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.10/dist-packages (from arch) (1.25.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.10/dist-packages (from arch) (1.11.4)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.10/dist-packages (from arch) (1.5.3)
# Requirement already satisfied: statsmodels>=0.12 in /usr/local/lib/python3.10/dist-packages (from arch) (0.14.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->arch) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->arch) (2023.4)
# Requirement already satisfied: patsy>=0.5.4 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.12->arch) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.12->arch) (23.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.4->statsmodels>=0.12->arch) (1.16.0)
# Requirement already satisfied: arch in /usr/local/lib/python3.10/dist-packages (6.3.0)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.10/dist-packages (from arch) (1.25.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.10/dist-packages (from arch) (1.11.4)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.10/dist-packages (from arch) (1.5.3)
# Requirement already satisfied: statsmodels>=0.12 in /usr/local/lib/python3.10/dist-packages (from arch) (0.14.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->arch) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->arch) (2023.4)
# Requirement already satisfied: patsy>=0.5.4 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.12->arch) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.12->arch) (23.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.4->statsmodels>=0.12->arch) (1.16.0)

# %%
from arch import arch_model

# %% [markdown]
# Загрузка исследуемого временного ряда и его визуализация:

# %%
series = pd.read_csv("monthly-sales-of-company-x-jan-6.csv")['Count']

# %%
plt.plot(series)
plt.title('Продажи компании Х')
plt.show()

# %% [markdown]
# Функции для проверки на стационарность и вывода графиков:

# %%
def test_stationarity(timeseries):
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
    for [key, value] in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)

# %%
def tsplot(y, lags=None, figsize=(14, 8), style='bmh'):
    test_stationarity(y)
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
    with plt.style.context(style):
        plt.figure(figsize=figsize)
        layout = (4, 1)
        ts_ax = plt.subplot2grid(layout, (0, 0), rowspan=2)
        acf_ax = plt.subplot2grid(layout, (2, 0))
        pacf_ax = plt.subplot2grid(layout, (3, 0))

        y.plot(ax=ts_ax, color='blue', label='Or')
        ts_ax.set_title('Original')

        smt.graphics.plot_acf(y, lags=lags, ax=acf_ax, alpha=0.05)
        smt.graphics.plot_pacf(y, lags=lags, ax=pacf_ax, alpha=0.05)

        plt.tight_layout()
    return

# %% [markdown]
# Перед GARCH-моделированием, необходимо исключить из ряда трендовую и сезонную составляющие. Для этого воспользуемся моделью ARIMA, и определим для нее оптимальные параметры.

# %% [markdown]
# Функции для подбора оптимальных параметров (p, d, q) ARIMA-модели методом поиска по сетке (Grid Search):

# %%
def evaluate_arima_model(X, arima_order):
  # Разделение ряда на обучающую (60%) и тестовую (40%) части:
  train_size = int(len(X) * 0.6)
  train, test = X[0:train_size], X[train_size:]
  history = [x for x in train]
  # Список с предсказанными значениями:
  predictions = list()
  for t in range(len(test)):
    model = ARIMA(history, order=arima_order)
    model_fit = model.fit()
    yhat = model_fit.forecast()[0]
    predictions.append(yhat)
    history.append(test[t])
    # Подсчет ошибки RMSE:
  rmse = sqrt(mean_squared_error(test, predictions))
  return rmse

# Оценка оптимальной комбинации параметров p, d, q:
def evaluate_models(dataset, p_values, d_values, q_values):
  dataset = dataset.astype('float32')
  best_score, best_cfg = float("inf"), None
  for p in p_values:
    for d in d_values:
      for q in q_values:
        order = (p,d,q)
        try:
          rmse = evaluate_arima_model(dataset, order)
          if rmse < best_score:
            best_score, best_cfg = rmse, order
            print('ARIMA%s RMSE=%.3f' % (order,rmse))
        except:
          continue
  print('Best ARIMA%s RMSE=%.3f' % (best_cfg, best_score))

# %%
series_arima = pd.read_csv('monthly-sales-of-company-x-jan-6.csv', header=0, index_col=0, parse_dates=True)
# Диапазоны значений параметров для перебора:
p_values = [4, 12]
d_values = [2, 3]
q_values = range(2, 3)
warnings.filterwarnings("ignore")
evaluate_models(series_arima.values, p_values, d_values, q_values)
# Out:
# ARIMA(4, 2, 2) RMSE=119.456
# ARIMA(12, 2, 2) RMSE=72.569
# Best ARIMA(12, 2, 2) RMSE=72.569

# %% [markdown]
# Модель ARIMA с полученным выше лучшим сочетанием параметров:

# %%
model = ARIMA(series, order=(12,2,2))
model_fit = model.fit()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %% [markdown]
# График остатков:

# %%
tsplot(model_fit.resid)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.026764e+01
# p-value                        4.079371e-18
# #Lags Used                     0.000000e+00
# Number of Observations Used    7.600000e+01
# Critical Value (1%)           -3.519481e+00
# Critical Value (5%)           -2.900395e+00
# Critical Value (10%)          -2.587498e+00
# dtype: float64

# %% [markdown]
# График остатков напоминает график стационарного ряда, но на нем присутсвуют заметные пики.

# %% [markdown]
# Обучение модели GARCH с полученными выше оптимальными значениями параметров:

# %%
garch_model = arch_model(series, mean='HAR', vol='GARCH', p=12, q=2, lags=2)
res_fit = garch_model.fit()
print(res_fit.summary())
# Out:
# Iteration:      1,   Func. Count:     20,   Neg. LLF: 64859.14187164051
# Iteration:      2,   Func. Count:     43,   Neg. LLF: 437.8979781791567
# Iteration:      3,   Func. Count:     63,   Neg. LLF: 441.5560911241214
# Iteration:      4,   Func. Count:     83,   Neg. LLF: 445.8500061652801
# Iteration:      5,   Func. Count:    103,   Neg. LLF: 430.66730886962665
# Iteration:      6,   Func. Count:    122,   Neg. LLF: 446.2303543587067
# Iteration:      7,   Func. Count:    144,   Neg. LLF: 540.5331378498233
# Iteration:      8,   Func. Count:    165,   Neg. LLF: 441.3864162916466
# Iteration:      9,   Func. Count:    185,   Neg. LLF: 428.43368545740594
# Iteration:     10,   Func. Count:    204,   Neg. LLF: 441.83212063981466
# Iteration:     11,   Func. Count:    224,   Neg. LLF: 427.9257063856683
# Iteration:     12,   Func. Count:    243,   Neg. LLF: 427.9591042325607
# Iteration:     13,   Func. Count:    263,   Neg. LLF: 427.6685916100303
# Iteration:     14,   Func. Count:    282,   Neg. LLF: 427.4775481009801
# Iteration:     15,   Func. Count:    301,   Neg. LLF: 427.32462695849176
# Iteration:     16,   Func. Count:    320,   Neg. LLF: 426.91871884925087
# Iteration:     17,   Func. Count:    339,   Neg. LLF: 426.4213535887092
# Iteration:     18,   Func. Count:    358,   Neg. LLF: 426.23910257323126
# Iteration:     19,   Func. Count:    377,   Neg. LLF: 426.1987624392268
# Iteration:     20,   Func. Count:    396,   Neg. LLF: 425.9940668866514
# Iteration:     21,   Func. Count:    415,   Neg. LLF: 425.48575681166477
# Iteration:     22,   Func. Count:    434,   Neg. LLF: 425.0470431168495
# Iteration:     23,   Func. Count:    453,   Neg. LLF: 424.796789769783
# Iteration:     24,   Func. Count:    472,   Neg. LLF: 424.7437508238163
# Iteration:     25,   Func. Count:    491,   Neg. LLF: 424.73768869994706
# Iteration:     26,   Func. Count:    510,   Neg. LLF: 424.7347971129137
# Iteration:     27,   Func. Count:    529,   Neg. LLF: 424.7347631211901
# Iteration:     28,   Func. Count:    549,   Neg. LLF: 424.73461325931066
# Iteration:     29,   Func. Count:    568,   Neg. LLF: 424.734608975438
# Iteration:     30,   Func. Count:    587,   Neg. LLF: 424.73459279578594
# Iteration:     31,   Func. Count:    606,   Neg. LLF: 424.7345534477682
# Iteration:     32,   Func. Count:    625,   Neg. LLF: 424.7344475171178
# Iteration:     33,   Func. Count:    644,   Neg. LLF: 424.7341824354829
# Iteration:     34,   Func. Count:    663,   Neg. LLF: 424.7334472335157
# Iteration:     35,   Func. Count:    682,   Neg. LLF: 424.73153834733085
# Iteration:     36,   Func. Count:    701,   Neg. LLF: 424.7267138904706
# Iteration:     37,   Func. Count:    720,   Neg. LLF: 424.7139387930521
# Iteration:     38,   Func. Count:    739,   Neg. LLF: 424.6811872507518
# Iteration:     39,   Func. Count:    758,   Neg. LLF: 424.63117440491357
# Iteration:     40,   Func. Count:    777,   Neg. LLF: 425.0832687279871
# Iteration:     41,   Func. Count:    797,   Neg. LLF: 424.07178589501063
# Iteration:     42,   Func. Count:    816,   Neg. LLF: 423.88754714466813
# Iteration:     43,   Func. Count:    836,   Neg. LLF: 423.5717617382249
# Iteration:     44,   Func. Count:    855,   Neg. LLF: 423.4273873149693
# Iteration:     45,   Func. Count:    874,   Neg. LLF: 423.303619600512
# Iteration:     46,   Func. Count:    893,   Neg. LLF: 423.2679132578948
# Iteration:     47,   Func. Count:    912,   Neg. LLF: 423.2798747855767
# Iteration:     48,   Func. Count:    932,   Neg. LLF: 423.2422933380133
# Iteration:     49,   Func. Count:    951,   Neg. LLF: 423.24207651518634
# Iteration:     50,   Func. Count:    970,   Neg. LLF: 435.60566220073133
# Iteration:     51,   Func. Count:    993,   Neg. LLF: 431.0687026669502
# Iteration:     52,   Func. Count: 1.02e+03,   Neg. LLF: 423.5840081802453
# Iteration:     53,   Func. Count: 1.04e+03,   Neg. LLF: 423.4782978912956
# Iteration:     54,   Func. Count: 1.06e+03,   Neg. LLF: 423.44015065820787
# Iteration:     55,   Func. Count: 1.08e+03,   Neg. LLF: 423.2790536532789
# Iteration:     56,   Func. Count: 1.1e+03,   Neg. LLF: 423.24226684826544
# Iteration:     57,   Func. Count: 1.12e+03,   Neg. LLF: 423.24231212731945
# Iteration:     58,   Func. Count: 1.14e+03,   Neg. LLF: 423.24220012762095
# Iteration:     59,   Func. Count: 1.16e+03,   Neg. LLF: 423.2422003680754
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 423.24220012762095
#             Iterations: 60
#             Function evaluations: 1159
#             Gradient evaluations: 59
#                           HAR - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  Count   R-squared:                       0.765
# Mean Model:                       HAR   Adj. R-squared:                  0.758
# Vol Model:                      GARCH   Log-Likelihood:               -423.242
# Distribution:                  Normal   AIC:                           882.484
# Method:            Maximum Likelihood   BIC:                           924.199
#                                         No. Observations:                   75
# Date:                Wed, Mar 06 2024   Df Residuals:                       72
# Time:                        17:13:26   Df Model:                            3
#                                 Mean Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# Const         21.2655      3.498      6.079  1.207e-09   [ 14.410, 28.121]
# Count[0:1]     1.3756      0.201      6.853  7.217e-12   [  0.982,  1.769]
# Count[0:2]    -0.3897      0.212     -1.836  6.638e-02 [ -0.806,2.634e-02]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      7.7851e-05     34.811  2.236e-06      1.000      [-68.228, 68.228]
# alpha[1]   2.0071e-11      0.133  1.507e-10      1.000      [ -0.261,  0.261]
# alpha[2]       0.0000  4.716e-02      0.000      1.000 [-9.244e-02,9.244e-02]
# alpha[3]       0.0270  5.316e-02      0.508      0.611   [-7.719e-02,  0.131]
# alpha[4]       0.0000  3.484e-02      0.000      1.000 [-6.829e-02,6.829e-02]
# alpha[5]       0.0000  8.936e-02      0.000      1.000      [ -0.175,  0.175]
# alpha[6]       0.0000  1.867e-02      0.000      1.000 [-3.659e-02,3.659e-02]
# alpha[7]       0.2040      0.107      1.905  5.674e-02   [-5.850e-03,  0.414]
# alpha[8]       0.0289  3.151e-02      0.917      0.359 [-3.287e-02,9.065e-02]
# alpha[9]       0.0000  7.345e-02      0.000      1.000      [ -0.144,  0.144]
# alpha[10]      0.0463  3.918e-02      1.181      0.237   [-3.050e-02,  0.123]
# alpha[11]      0.0000  5.100e-02      0.000      1.000 [-9.995e-02,9.995e-02]
# alpha[12]      0.6858      0.162      4.222  2.418e-05      [  0.367,  1.004]
# beta[1]    8.0826e-03      0.127  6.361e-02      0.949      [ -0.241,  0.257]
# beta[2]        0.0000  9.602e-02      0.000      1.000      [ -0.188,  0.188]
# =============================================================================
#
# Covariance estimator: robust

# %% [markdown]
# График остатков:

# %%
res_fit.plot()

# %% [markdown]
# График остатков сравним с полученным ранее на модели ARIMA.
# Попробуем применить к ряду преобразование Бокса-Кокса и дифференцирование с лагом 7 и 12 (в сводке коэффициенты альфа [7] и [12] сильнее остальных отличаются от нуля), после чего еще раз применим моделирование GARCH.

# %%
from scipy.stats import boxcox

# %%
series_x = boxcox(series, 0) # убираем нарастание дисперсии
series_x = series_x[7:] - series_x[:-7] # убираем тренд
series_x = series_x[12:] - series_x[:-12] # убираем сезонность

# %%
series_x = pd.Series(series_x)

# %%
series_x.isna().sum()
# Out:
# 0

# %% [markdown]
# GARCH-модель ряда после преобразований:

# %%
garch_model_2 = arch_model(series_x, mean='HAR', vol='GARCH', p=12, q=2, lags=2)
res_fit_2 = garch_model_2.fit()
print(res_fit_2.summary())
# Out:
# Iteration:      1,   Func. Count:     20,   Neg. LLF: 67611835.45122087
# Iteration:      2,   Func. Count:     41,   Neg. LLF: 1286.208306171993
# Iteration:      3,   Func. Count:     63,   Neg. LLF: 13840.446812250499
# Iteration:      4,   Func. Count:     84,   Neg. LLF: 99.83897085981096
# Iteration:      5,   Func. Count:    105,   Neg. LLF: 9.269875115240627
# Iteration:      6,   Func. Count:    126,   Neg. LLF: 17.07671974828
# Iteration:      7,   Func. Count:    146,   Neg. LLF: 8.260284979989265
# Iteration:      8,   Func. Count:    165,   Neg. LLF: 17.481437189857587
# Iteration:      9,   Func. Count:    185,   Neg. LLF: 11.861728014184685
# Iteration:     10,   Func. Count:    205,   Neg. LLF: 9.89328746982465
# Iteration:     11,   Func. Count:    225,   Neg. LLF: 7.8379459501103375
# Iteration:     12,   Func. Count:    245,   Neg. LLF: 6.767466902515324
# Iteration:     13,   Func. Count:    264,   Neg. LLF: 9.85904011147948
# Iteration:     14,   Func. Count:    285,   Neg. LLF: 7.847853638105411
# Iteration:     15,   Func. Count:    305,   Neg. LLF: 6.678702241306446
# Iteration:     16,   Func. Count:    325,   Neg. LLF: 6.629935842047875
# Iteration:     17,   Func. Count:    344,   Neg. LLF: 6.799735156509859
# Iteration:     18,   Func. Count:    364,   Neg. LLF: 6.623914910896906
# Iteration:     19,   Func. Count:    384,   Neg. LLF: 6.606871449168358
# Iteration:     20,   Func. Count:    403,   Neg. LLF: 6.6048804075426
# Iteration:     21,   Func. Count:    422,   Neg. LLF: 6.603980586527394
# Iteration:     22,   Func. Count:    441,   Neg. LLF: 6.605576594247272
# Iteration:     23,   Func. Count:    461,   Neg. LLF: 6.587983241817346
# Iteration:     24,   Func. Count:    480,   Neg. LLF: 6.5784980597958445
# Iteration:     25,   Func. Count:    499,   Neg. LLF: 6.577142811074185
# Iteration:     26,   Func. Count:    518,   Neg. LLF: 6.576493239103061
# Iteration:     27,   Func. Count:    537,   Neg. LLF: 6.576026854471822
# Iteration:     28,   Func. Count:    556,   Neg. LLF: 6.561338417098327
# Iteration:     29,   Func. Count:    575,   Neg. LLF: 6.491063182802084
# Iteration:     30,   Func. Count:    594,   Neg. LLF: 6.521972968716599
# Iteration:     31,   Func. Count:    623,   Neg. LLF: 6.482289839603123
# Iteration:     32,   Func. Count:    642,   Neg. LLF: 2645.8473332640915
# Iteration:     33,   Func. Count:    664,   Neg. LLF: 2222.518754658683
# Iteration:     34,   Func. Count:    686,   Neg. LLF: 178.28975731479917
# Iteration:     35,   Func. Count:    707,   Neg. LLF: 9.751067561945849
# Iteration:     36,   Func. Count:    727,   Neg. LLF: 8.716370436365105
# Iteration:     37,   Func. Count:    747,   Neg. LLF: 7.373620923086129
# Iteration:     38,   Func. Count:    767,   Neg. LLF: 6.84242623182297
# Iteration:     39,   Func. Count:    787,   Neg. LLF: 6.439162407131034
# Iteration:     40,   Func. Count:    807,   Neg. LLF: 6.9711386504682835
# Iteration:     41,   Func. Count:    828,   Neg. LLF: 6.441551713254594
# Iteration:     42,   Func. Count:    848,   Neg. LLF: 6.434508832283736
# Iteration:     43,   Func. Count:    868,   Neg. LLF: 6.433977809608584
# Iteration:     44,   Func. Count:    888,   Neg. LLF: 6.433850011390001
# Iteration:     45,   Func. Count:    907,   Neg. LLF: 6.43384912921468
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 6.43384912921468
#             Iterations: 46
#             Function evaluations: 907
#             Gradient evaluations: 45
#                           HAR - GARCH Model Results
# ==============================================================================
# Dep. Variable:                   None   R-squared:                       0.294
# Mean Model:                       HAR   Adj. R-squared:                  0.267
# Vol Model:                      GARCH   Log-Likelihood:               -6.43385
# Distribution:                  Normal   AIC:                           48.8677
# Method:            Maximum Likelihood   BIC:                           85.3240
#                                         No. Observations:                   56
# Date:                Wed, Mar 06 2024   Df Residuals:                       53
# Time:                        17:13:56   Df Model:                            3
#                                  Mean Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# Const         -0.0173  7.399e-02     -0.234      0.815    [ -0.162,  0.128]
# None[0:1]      0.0477      0.226      0.211      0.833    [ -0.395,  0.490]
# None[0:2]      0.4562      0.234      1.949  5.129e-02 [-2.565e-03,  0.915]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega          0.0134  1.810e-02      0.740      0.459 [-2.207e-02,4.886e-02]
# alpha[1]       0.0904      0.263      0.343      0.732      [ -0.426,  0.607]
# alpha[2]   1.1987e-12      0.123  9.760e-12      1.000      [ -0.241,  0.241]
# alpha[3]   4.1853e-13      0.151  2.776e-12      1.000      [ -0.296,  0.296]
# alpha[4]   2.5870e-12  3.684e-02  7.023e-11      1.000 [-7.220e-02,7.220e-02]
# alpha[5]   4.5625e-13      0.144  3.161e-12      1.000      [ -0.283,  0.283]
# alpha[6]   6.7570e-13  6.308e-02  1.071e-11      1.000      [ -0.124,  0.124]
# alpha[7]       0.1598      0.317      0.504      0.615      [ -0.462,  0.782]
# alpha[8]   3.5528e-13      0.177  2.008e-12      1.000      [ -0.347,  0.347]
# alpha[9]   7.7234e-13  8.832e-02  8.745e-12      1.000      [ -0.173,  0.173]
# alpha[10]      0.1008      0.241      0.418      0.676      [ -0.372,  0.573]
# alpha[11]  9.8087e-13  7.668e-02  1.279e-11      1.000      [ -0.150,  0.150]
# alpha[12]      0.5602      0.398      1.408      0.159      [ -0.219,  1.340]
# beta[1]    1.8201e-12      0.114  1.590e-11      1.000      [ -0.224,  0.224]
# beta[2]        0.0744      0.201      0.371      0.711      [ -0.319,  0.467]
# =============================================================================
#
# Covariance estimator: robust

# %% [markdown]
# График остатков:

# %%
res_fit_2.plot()

# %% [markdown]
# Теперь гарфик остатков стал больше похож на белый шум. Судя по всему, для получения качественного результата для ряда без предварительных преобразований, необходима более тщательная настройка гиперпараметров модели GARCH, лучший подбор параметров (p, d, q) модели ARIMA или использование для этого другой модели, например SARIMA для подобного характера исходного временного ряда.
